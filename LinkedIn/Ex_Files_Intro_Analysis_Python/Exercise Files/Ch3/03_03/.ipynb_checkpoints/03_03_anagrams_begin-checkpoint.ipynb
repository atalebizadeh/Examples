# %%
word = open('words','r')

# %%
word
# Out:
# <_io.TextIOWrapper name='words' mode='r' encoding='cp1252'>

# %%
wordlist = word.readlines()

# %%
wordlist[:10]
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n']

# %%
len(wordlist)
# Out:
# 235886

# %%
'Aaron\n'.strip()
# Out:
# 'Aaron'

# %%
'Aaron'.lower()
# Out:
# 'aaron'

# %%
wordclean = [word.strip().lower() for word in wordlist]

# %%
wordclean[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
wordunique = list(set(wordclean))

# %%
wordunique
# Out:
# ['hesiodic',
#  'breakstone',
#  'disproportionate',
#  'reobjectivization',
#  'manageress',
#  'patu',
#  'sapan',
#  'unpermitted',
#  'upbreak',
#  'slummocky',
#  'defusion',
#  'provine',
#  'upwith',
#  'marybud',
#  'papule',
#  'mechanistically',
#  'poral',
#  'endosalpingitis',
#  'gariba',
#  'brume',
#  'confabulatory',
#  'supralineal',
#  'daffish',
#  'eremite',
#  'venenific',
#  'penorcon',
#  'behowl',
#  'antireticular',
#  'egueiite',
#  'antineutral',
#  'ophiobolus',
#  'uncombustible',
#  'goldenpert',
#  'insurrectionist',
#  'scacchic',
#  'storming',
#  'nonpredictable',
#  'parader',
#  'verumontanum',
#  'thralldom',
#  'adzooks',
#  'allotriodontia',
#  'dacrycystalgia',
#  'heterogen',
#  'perversive',
#  'triseme',
#  'unattackable',
#  'surging',
#  'myrmeleon',
#  'aztec',
#  'aphengoscope',
#  'overlearnedness',
#  'blindness',
#  'folkvang',
#  'malunion',
#  'ultrawealthy',
#  'thermostatically',
#  'dor',
#  'pandarus',
#  'tummock',
#  'transcendentality',
#  'quinquecostate',
#  'wordily',
#  'shippon',
#  'hallucinate',
#  'preinducement',
#  'submicroscopically',
#  'counterdisengagement',
#  'fluotantalate',
#  'reconcilement',
#  'uncorruptibly',
#  'humidistat',
#  'petticoatless',
#  'engerminate',
#  'forepale',
#  'geophagy',
#  'ugsomely',
#  'redisseize',
#  'theatrophonic',
#  'trapshooting',
#  'hurleyhouse',
#  'stainless',
#  'unlabiate',
#  'unsufficience',
#  'assaultable',
#  'overstiff',
#  'pindarism',
#  'garookuh',
#  'proromance',
#  'smolder',
#  'irenicum',
#  'jacobinia',
#  'impasse',
#  'kyphosis',
#  'rhexis',
#  'exencephalus',
#  'coprecipitate',
#  'drabble',
#  'platiniridium',
#  'portulacaria',
#  'rohun',
#  'vecture',
#  'calathiscus',
#  'candolleaceae',
#  'docilely',
#  'istle',
#  'unpleasantish',
#  'inspiriter',
#  'leucospermous',
#  'ratement',
#  'nemocerous',
#  'rosehead',
#  'saloonkeeper',
#  'leposternidae',
#  'computist',
#  'craniomaxillary',
#  'pterygotrabecular',
#  'reflourishment',
#  'entrancing',
#  'kanap',
#  'zooter',
#  'versionist',
#  'haemaspectroscope',
#  'hymenopterous',
#  'diluent',
#  'foilable',
#  'pointways',
#  'uncompared',
#  'usher',
#  'leucocythemic',
#  'mallangong',
#  'gastronomic',
#  'unswabbed',
#  'seductive',
#  'shina',
#  'vexillation',
#  'dumbbell',
#  'decahedron',
#  'tubber',
#  'nivellization',
#  'stormable',
#  'unacquirable',
#  'theologicomilitary',
#  'underprint',
#  'lockmaking',
#  'overvoltage',
#  'posteriad',
#  'unkamed',
#  'limnology',
#  'quadriphosphate',
#  'tarumari',
#  'hydrorubber',
#  'dogless',
#  'nonindictable',
#  'jackshay',
#  'pensively',
#  'umbrella',
#  'labrusca',
#  'preaccount',
#  'leptolepis',
#  'strophulus',
#  'isovalerate',
#  'heterotrophic',
#  'quackhood',
#  'graypate',
#  'growthiness',
#  'ineligibly',
#  'ulotrichy',
#  'tinklerman',
#  'paraglossal',
#  'hepatoduodenal',
#  'matchmark',
#  'bazooka',
#  'canister',
#  'natiform',
#  'outhunt',
#  'repronounce',
#  'sefekhet',
#  'suboval',
#  'usually',
#  'anerly',
#  'circaea',
#  'omer',
#  'squinted',
#  'pincian',
#  'sinneress',
#  'pelagic',
#  'pitiable',
#  'disgorgement',
#  'abandonment',
#  'insensibilize',
#  'loopful',
#  'upholsterydom',
#  'osteoporotic',
#  'biogeographically',
#  'trachypteroid',
#  'overshadowingly',
#  'paludamentum',
#  'tyriasis',
#  'congou',
#  'allokurtic',
#  'coudee',
#  'redient',
#  'unimposedly',
#  'overquickly',
#  'prescindent',
#  'antiphonal',
#  'unaspiringly',
#  'prerestrict',
#  'proconventional',
#  'unsproutful',
#  'pigmentary',
#  'unsin',
#  'salsify',
#  'unchasteness',
#  'ampelite',
#  'anonymousness',
#  'languaged',
#  'privativeness',
#  'gnathic',
#  'peragrate',
#  'sig',
#  'stylidiaceous',
#  'fornication',
#  'azurite',
#  'clammyweed',
#  'phosphotungstate',
#  'pretraditional',
#  'relimit',
#  'gustation',
#  'hyperfunctional',
#  'isolating',
#  'strophiolated',
#  'stypticity',
#  'supercompetition',
#  'blatta',
#  'unmeliorated',
#  'lonchopteridae',
#  'unforetold',
#  'unhermetic',
#  'azimene',
#  'pentametrize',
#  'crepitus',
#  'profitmonger',
#  'subcutaneously',
#  'haploidy',
#  'acleistous',
#  'philhellenic',
#  'multifidly',
#  'aminoethionic',
#  'wholeness',
#  'imbed',
#  'thankee',
#  'microphallus',
#  'snoreless',
#  'advowee',
#  'heloma',
#  'thruster',
#  'compression',
#  'mirate',
#  'semiterrestrial',
#  'polydactylism',
#  'vermiformia',
#  'amusement',
#  'worden',
#  'pyopericardium',
#  'bigheartedness',
#  'magalensia',
#  'nonperformance',
#  'overinventoried',
#  'unavailful',
#  'isocyclic',
#  'dori',
#  'phrenospasm',
#  'avaremotemo',
#  'jinglingly',
#  'anthokyan',
#  'macrosplanchnic',
#  'bekinkinite',
#  'binormal',
#  'histological',
#  'recontrive',
#  'quiteno',
#  'unbowingness',
#  'grinch',
#  'necker',
#  'galactosis',
#  'galanas',
#  'bibio',
#  'panade',
#  'cinematographical',
#  'insalivate',
#  'obliviousness',
#  'triazine',
#  'prerolandic',
#  'stethospasm',
#  'graphology',
#  'prejudiciously',
#  'resatisfy',
#  'zanzalian',
#  'whuff',
#  'napoleonite',
#  'lunged',
#  'panhellenism',
#  'retarder',
#  'haaf',
#  'reproduction',
#  'unspectrelike',
#  'chymous',
#  'mermaid',
#  'eurygnathous',
#  'hypodiapason',
#  'viduine',
#  'mimography',
#  'vermeology',
#  'mouser',
#  'musculophrenic',
#  'auxochrome',
#  'encrinital',
#  'uncompletely',
#  'palaeolimnology',
#  'tainture',
#  'pteraspis',
#  'unzone',
#  'relessor',
#  'purulently',
#  'trolleite',
#  'unipulse',
#  'columbian',
#  'bradyphasia',
#  'centroplasm',
#  'neumic',
#  'bloodshedding',
#  'leucothea',
#  'singspiel',
#  'bostrychidae',
#  'avaradrano',
#  'streptaster',
#  'bennel',
#  'notour',
#  'airdrome',
#  'sabbath',
#  'unmilitaristic',
#  'ravensara',
#  'blueprinter',
#  'urial',
#  'overtimbered',
#  'chitrali',
#  'twizzle',
#  'inigo',
#  'infirmity',
#  'preallow',
#  'gardenly',
#  'adenasthenia',
#  'beautification',
#  'paleohydrography',
#  'leftward',
#  'pingle',
#  'befleck',
#  'odzooks',
#  'conversationable',
#  'asthenobiotic',
#  'unfeline',
#  'gawkihood',
#  'knuckled',
#  'transfrontier',
#  'unintroitive',
#  'unseemly',
#  'andromedotoxin',
#  'induviate',
#  'boltmaker',
#  'pilocystic',
#  'difformed',
#  'naticine',
#  'secretomotor',
#  'sulphatization',
#  'wapp',
#  'hibernation',
#  'cyclar',
#  'timework',
#  'arsenicophagy',
#  'preteritness',
#  'cantoner',
#  'ant',
#  'tatu',
#  'treewards',
#  'zonelet',
#  'penicilliform',
#  'vesicoabdominal',
#  'mussaenda',
#  'usedness',
#  'pusillanimous',
#  'indigo',
#  'pitifully',
#  'homography',
#  'portension',
#  'dimmet',
#  'photospectroscopy',
#  'septentrionic',
#  'subdititious',
#  'explorement',
#  'resue',
#  'unfailingly',
#  'reflectance',
#  'limberness',
#  'negativeness',
#  'pima',
#  'strabismic',
#  'zone',
#  'trypographic',
#  'serpulidan',
#  'tchetnitsi',
#  'conflagrator',
#  'ecstrophy',
#  'metapsychist',
#  'elvish',
#  'leucadian',
#  'highliving',
#  'visitandine',
#  'disseizor',
#  'incensurably',
#  'methylate',
#  'homologic',
#  'chal',
#  'mince',
#  'untranquillize',
#  'benzil',
#  'pretympanic',
#  'gladfulness',
#  'puzzledness',
#  'haloragidaceae',
#  'unamalgamated',
#  'masterwort',
#  'potcrook',
#  'coolen',
#  'alvah',
#  'irritating',
#  'antipodagron',
#  'competency',
#  'elenchtical',
#  'toernebohmite',
#  'vestibulospinal',
#  'laterally',
#  'askar',
#  'bannered',
#  'calcitic',
#  'republicanization',
#  'bangiales',
#  'menstruate',
#  'exulcerative',
#  'bathvillite',
#  'sparkless',
#  'electrotonize',
#  'orbitelous',
#  'kelpie',
#  'brangler',
#  'ironshot',
#  'seiche',
#  'pompless',
#  'sociolegal',
#  'speechfulness',
#  'imputrescence',
#  'dom',
#  'inorb',
#  'oneirocritically',
#  'pictorially',
#  'retch',
#  'imposturism',
#  'rue',
#  'constrainable',
#  'guaiac',
#  'ungues',
#  'distinguishability',
#  'hurrisome',
#  'pishogue',
#  'acetylenation',
#  'mazolytic',
#  'royetously',
#  'wolfhood',
#  'ventroscopy',
#  'unfledged',
#  'guanosine',
#  'scrofuloderma',
#  'surfbird',
#  'unnominated',
#  'credencive',
#  'pronger',
#  'redheadedly',
#  'ataxiagram',
#  'butteris',
#  'popularity',
#  'psychologics',
#  'dishonorableness',
#  'baddishness',
#  'consecutives',
#  'proconservation',
#  'agnostus',
#  'haemoconcentration',
#  'quakerlet',
#  'disincarnation',
#  'polydactyl',
#  'recoupable',
#  'varietism',
#  'fiendship',
#  'profession',
#  'retinispora',
#  'axoneure',
#  'umbiliform',
#  'leisureless',
#  'newichawanoc',
#  'stammeringly',
#  'earjewel',
#  'postdural',
#  'spectrography',
#  'tenderability',
#  'oiltightness',
#  'tarantulism',
#  'malvolition',
#  'cursively',
#  'salmwood',
#  'counterspying',
#  'endotheliotoxin',
#  'unfusibly',
#  'dust',
#  'branchipus',
#  'equableness',
#  'subradical',
#  'ravening',
#  'convulsively',
#  'eurafrican',
#  'refiningly',
#  'righteously',
#  'representable',
#  'glossopodium',
#  'guaka',
#  'barrett',
#  'geomagnetician',
#  'glottological',
#  'intoxication',
#  'keelless',
#  'unlaved',
#  'anerythroplastic',
#  'demicivilized',
#  'bandhu',
#  'transduction',
#  'unconsidering',
#  'arctium',
#  'salaried',
#  'unrehearsing',
#  'scuttle',
#  'oraculousness',
#  'recreative',
#  'soxhlet',
#  'termin',
#  'spalpeen',
#  'atropic',
#  'ramusi',
#  'screwbarrel',
#  'unaudible',
#  'honeylipped',
#  'waesome',
#  'sheriff',
#  'frontward',
#  'adenosarcoma',
#  'babacoote',
#  'arsenicize',
#  'russophobism',
#  'densen',
#  'cambalo',
#  'unrevolving',
#  'cecidomyiidae',
#  'nectopod',
#  'ruffin',
#  'louisiana',
#  'viticultural',
#  'anterevolutional',
#  'catabasis',
#  'rotate',
#  'zendik',
#  'alsinaceae',
#  'porkpie',
#  'bargainwise',
#  'evasive',
#  'recommend',
#  'grappler',
#  'imprimitive',
#  'corenounce',
#  'adobe',
#  'floodwater',
#  'hypotarsal',
#  'periclinally',
#  'excludable',
#  'clumsiness',
#  'docetistic',
#  'pacchionian',
#  'incultivation',
#  'villain',
#  'committer',
#  'unmulled',
#  'sinuauricular',
#  'blepharocera',
#  'periangiocholitis',
#  'thelemite',
#  'disconanthae',
#  'sprod',
#  'lenient',
#  'millioctave',
#  'wittawer',
#  'dragon',
#  'quadriciliate',
#  'actaeon',
#  'trivialness',
#  'pentadactylate',
#  'jollity',
#  'stingy',
#  'outtaken',
#  'unglorified',
#  'binodose',
#  'unilateralization',
#  'ungraciousness',
#  'monotelephonic',
#  'octospore',
#  'pseudomelanosis',
#  'anopheles',
#  'distinguishing',
#  'campanularian',
#  'heraldize',
#  'nucleate',
#  'sesquiquintile',
#  'daimen',
#  'pleochroism',
#  'overjudging',
#  'termitophilous',
#  'rockiness',
#  'microscopist',
#  'polygonia',
#  'flemish',
#  'consternate',
#  'ancylodactyla',
#  'immediateness',
#  'elocular',
#  'shiner',
#  'emphatical',
#  'conjointly',
#  'pachydermatosis',
#  'groundnut',
#  'deresinate',
#  'subiya',
#  'nosomycosis',
#  'mesolimnion',
#  'contingency',
#  'dentalgia',
#  'feebleheartedness',
#  'momentaneall',
#  'corynebacterium',
#  'homoeopathically',
#  'enmist',
#  'spellwork',
#  'puntabout',
#  'presufficiency',
#  'rewardedly',
#  'malefactress',
#  'amnesia',
#  'motorboatman',
#  'poulticewise',
#  'tripylaean',
#  'vouchsafement',
#  'unmuffled',
#  'acetylene',
#  'interruption',
#  'hornfair',
#  'alphean',
#  'bana',
#  'calathian',
#  'kaolinate',
#  'fairway',
#  'bisaltae',
#  'neophobia',
#  'beaverlike',
#  'dartlike',
#  'unprecipitated',
#  'pectinoid',
#  'tongrian',
#  'unprecedentedness',
#  'vermicious',
#  'macled',
#  'proclassical',
#  'telephonograph',
#  'staffed',
#  'lamasery',
#  'aponeurosis',
#  'gunnage',
#  'miserably',
#  'saturnine',
#  'diffuseness',
#  'aggregation',
#  'circumcentral',
#  'fasting',
#  'spet',
#  'variolate',
#  'faucre',
#  'sulphurate',
#  'unzealousness',
#  'kokoona',
#  'proseminar',
#  'subdemonstrate',
#  'unbalancing',
#  'fibrosis',
#  'anthropopithecus',
#  'nannyberry',
#  'penalist',
#  'underaim',
#  'prosodical',
#  'typobar',
#  'tchu',
#  'spurge',
#  'sartoriad',
#  'rearrest',
#  'circumbuccal',
#  'sialic',
#  'acroteric',
#  'synapsis',
#  'guild',
#  'zygomorphism',
#  'display',
#  'bouchal',
#  'thondraki',
#  'average',
#  'chuchona',
#  'unfundamental',
#  'unsampled',
#  'denotive',
#  'cremate',
#  'bung',
#  'paraphenylene',
#  'pseudostalactite',
#  'sporochnaceae',
#  'pigmental',
#  'aspergillin',
#  'isleted',
#  'hyperbolic',
#  'postanesthetic',
#  'coinherence',
#  'overpreface',
#  'quillet',
#  'superindignant',
#  'bromate',
#  'torsigraph',
#  'spasticity',
#  'suitableness',
#  'epidermolysis',
#  'rambutan',
#  'immunologically',
#  'batara',
#  'paunchiness',
#  'theogony',
#  'laria',
#  'violably',
#  'graze',
#  'pathological',
#  'priapulidae',
#  'trailman',
#  'intensively',
#  'footwork',
#  'japanese',
#  'mesorectal',
#  'acetanion',
#  'fronded',
#  'stilly',
#  'bionomist',
#  'tubifex',
#  'carbohemoglobin',
#  'curver',
#  'carchariidae',
#  'holopneustic',
#  'overslaugh',
#  'revers',
#  'promulge',
#  'decolorization',
#  'foliaceousness',
#  'megaspore',
#  'roughings',
#  'frantic',
#  'mammilliform',
#  'fet',
#  'quinquarticular',
#  'substitutingly',
#  'unfilled',
#  'forfar',
#  'orthoceran',
#  'notencephalocele',
#  'leopoldinia',
#  'thoroughness',
#  'parenthetical',
#  'perionychium',
#  'nosonomy',
#  'currier',
#  'busybodyism',
#  'zabaism',
#  'unlathed',
#  'nematoidea',
#  'subfactory',
#  'than',
#  'chokage',
#  'chromoprotein',
#  'inimical',
#  'periarthric',
#  'begone',
#  'cothurned',
#  'cornmaster',
#  'nitrosyl',
#  'temporary',
#  'unpersuasion',
#  'vitrophyric',
#  'smearless',
#  'demonstrativeness',
#  'zanyish',
#  'whimsied',
#  'kreng',
#  'hemichorda',
#  'creepmouse',
#  'sphenomaxillary',
#  'messmate',
#  'strad',
#  'arikara',
#  'intangibly',
#  'nephromere',
#  'sexradiate',
#  'catlin',
#  'hibernicism',
#  'trademaster',
#  'dibromid',
#  'nontrier',
#  'kyphoscoliosis',
#  'cetacea',
#  'reanchor',
#  'offenseful',
#  'erethismic',
#  'pouncer',
#  'semarum',
#  'caroa',
#  'uncriminal',
#  'nonsetting',
#  'hypothermia',
#  'hygrometry',
#  'reprune',
#  'removed',
#  'abeigh',
#  'apicular',
#  'londonization',
#  'sartorite',
#  'uncrystaled',
#  'oxreim',
#  'plouter',
#  'universologist',
#  'interrogatedness',
#  'especialness',
#  'solanaceae',
#  'unmodelled',
#  'manchesterdom',
#  'militariness',
#  'mosquital',
#  'mushabbihite',
#  'piligan',
#  'posterial',
#  'arthrosis',
#  'flitch',
#  'patripassianly',
#  'archiblastoma',
#  'plasmodiophoraceae',
#  'raceme',
#  'wat',
#  'occlusive',
#  'conchiolin',
#  'dendrophil',
#  'pityroid',
#  'affably',
#  'alcohol',
#  'rubberize',
#  'waggel',
#  'wileless',
#  'tourmalinize',
#  'polymeria',
#  'chalcidid',
#  'mullocky',
#  'phenomenalistic',
#  'ponderosapine',
#  'seminative',
#  'kissage',
#  'gorgonia',
#  'pulldown',
#  'miltwaste',
#  'ovey',
#  'gainsome',
#  'homeokinesis',
#  'inkerman',
#  'monkflower',
#  'ensuance',
#  'yarnwindle',
#  'microphotometer',
#  'vaginervose',
#  'productus',
#  'micromotion',
#  'guidepost',
#  'quadriparous',
#  'phrenitic',
#  'bosc',
#  'goods',
#  'unavoiding',
#  'tachiol',
#  'leucosis',
#  'zoosporiferous',
#  'unfountained',
#  'hexapodal',
#  'hornlessness',
#  'bayeta',
#  'mentary',
#  'urian',
#  'whinnock',
#  'cyamelide',
#  'pukeweed',
#  'mids',
#  'lymphoglandula',
#  'uncredited',
#  'cercal',
#  'manageableness',
#  'pasturability',
#  'proethnically',
#  'unfought',
#  'activation',
#  'ampelosicyos',
#  'daedalian',
#  'stretman',
#  'sandaracin',
#  'untartarized',
#  'acetobenzoic',
#  'postallantoic',
#  'araliaephyllum',
#  'superficialize',
#  'easeless',
#  'besplit',
#  'dowf',
#  'corsetless',
#  'spiralize',
#  'microcosmical',
#  'canker',
#  'bedel',
#  'ununitableness',
#  'daggle',
#  'boohoo',
#  'pleurobranchiate',
#  'phthisical',
#  'jam',
#  'postmaxillary',
#  'skiagraphical',
#  'distributive',
#  'cratinean',
#  'precipitately',
#  'spatilomancy',
#  'imbrex',
#  'falsary',
#  'stereochromic',
#  'dysarthrosis',
#  'oneiroscopy',
#  'carking',
#  'ecdysiast',
#  'nuchalgia',
#  'overcry',
#  'checkrowed',
#  'kenspeck',
#  'projudicial',
#  'unsanitary',
#  'miryachit',
#  'accessariness',
#  'cooperage',
#  'cibophobia',
#  'extinguisher',
#  'arteriole',
#  'horniness',
#  'idioblastic',
#  'comminution',
#  'piecemaker',
#  'veerable',
#  'unhusked',
#  'breakout',
#  'tufalike',
#  'outpray',
#  'ranzania',
#  'unlamed',
#  'apotheosis',
#  'antilia',
#  'angustifolious',
#  'bunsenite',
#  'clothesbasket',
#  'overnegligent',
#  'babe',
#  'popovets',
#  'gilder',
#  'jezebel',
#  'resurrectionist',
#  ...]

# %%
wordunique.sort()

# %%
wordunique[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
wordclean = [word.strip().lower() for word in open('words','r')]

# %%
wordclean[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
wordclean = sorted(list(set([word.strip().lower() for word in open('words','r')])))

# %%
wordclean[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
sorted('lives')
# Out:
# ['e', 'i', 'l', 's', 'v']

# %%
def signature(word):
    return ''.join(sorted(word))

# %%
signature('lives')
# Out:
# 'eilsv'

# %%
def anagram(myword):
    return [word for word in wordclean if signature(word) == signature(myword)]

# %%
anagram('dictionary')
# Out:
# ['dictionary', 'indicatory']

# %%
# %timeit anagram('dictionary')
# Out:
# 451 ms ± 69 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
