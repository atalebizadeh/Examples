# %%
import pandas as pd
import pandasql as ps

# %%
# cd which is short for CovidDeaths
cd = pd.read_excel('data/CovidDeaths.xlsx')
cd.head()
# Out:
#   iso_code continent     location       date  population  total_cases  \
# 0      AFG      Asia  Afghanistan 2020-02-24  38928341.0          1.0
# 1      AFG      Asia  Afghanistan 2020-02-25  38928341.0          1.0
# 2      AFG      Asia  Afghanistan 2020-02-26  38928341.0          1.0
# 3      AFG      Asia  Afghanistan 2020-02-27  38928341.0          1.0
# 4      AFG      Asia  Afghanistan 2020-02-28  38928341.0          1.0
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        1.0                 NaN           NaN         NaN  ...
# 1        0.0                 NaN           NaN         NaN  ...
# 2        0.0                 NaN           NaN         NaN  ...
# 3        0.0                 NaN           NaN         NaN  ...
# 4        0.0                 NaN           NaN         NaN  ...
#
#    new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# 0                              NaN                NaN           NaN
# 1                              NaN                NaN           NaN
# 2                              NaN                NaN           NaN
# 3                              NaN                NaN           NaN
# 4                              NaN                NaN           NaN
#
#    icu_patients_per_million  hosp_patients  hosp_patients_per_million  \
# 0                       NaN            NaN                        NaN
# 1                       NaN            NaN                        NaN
# 2                       NaN            NaN                        NaN
# 3                       NaN            NaN                        NaN
# 4                       NaN            NaN                        NaN
#
#    weekly_icu_admissions  weekly_icu_admissions_per_million  \
# 0                    NaN                                NaN
# 1                    NaN                                NaN
# 2                    NaN                                NaN
# 3                    NaN                                NaN
# 4                    NaN                                NaN
#
#    weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 0                     NaN                                 NaN
# 1                     NaN                                 NaN
# 2                     NaN                                 NaN
# 3                     NaN                                 NaN
# 4                     NaN                                 NaN
#
# [5 rows x 26 columns]

# %%
# cv which is short for CovidVaccinations
cv = pd.read_excel('data/CovidVaccinations.xlsx')
cv.head()
# Out:
#   iso_code continent     location       date  total_tests  \
# 0      AFG      Asia  Afghanistan 2020-02-24          NaN
# 1      AFG      Asia  Afghanistan 2020-02-25          NaN
# 2      AFG      Asia  Afghanistan 2020-02-26          NaN
# 3      AFG      Asia  Afghanistan 2020-02-27          NaN
# 4      AFG      Asia  Afghanistan 2020-02-28          NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  positive_rate  ...  gdp_per_capita  \
# 0                              NaN            NaN  ...        1803.987
# 1                              NaN            NaN  ...        1803.987
# 2                              NaN            NaN  ...        1803.987
# 3                              NaN            NaN  ...        1803.987
# 4                              NaN            NaN  ...        1803.987
#
#   extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 0             NaN                597.029                 9.59             NaN
# 1             NaN                597.029                 9.59             NaN
# 2             NaN                597.029                 9.59             NaN
# 3             NaN                597.029                 9.59             NaN
# 4             NaN                597.029                 9.59             NaN
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0           NaN                  37.746                         0.5
# 1           NaN                  37.746                         0.5
# 2           NaN                  37.746                         0.5
# 3           NaN                  37.746                         0.5
# 4           NaN                  37.746                         0.5
#
#    life_expectancy  human_development_index
# 0            64.83                    0.511
# 1            64.83                    0.511
# 2            64.83                    0.511
# 3            64.83                    0.511
# 4            64.83                    0.511
#
# [5 rows x 37 columns]

# %%
#to read cd table
ps.sqldf("select * from cd where continent is not null order by 3,4")
# Out:
#       iso_code continent     location                        date  population  \
# 0          AFG      Asia  Afghanistan  2020-02-24 00:00:00.000000  38928341.0
# 1          AFG      Asia  Afghanistan  2020-02-25 00:00:00.000000  38928341.0
# 2          AFG      Asia  Afghanistan  2020-02-26 00:00:00.000000  38928341.0
# 3          AFG      Asia  Afghanistan  2020-02-27 00:00:00.000000  38928341.0
# 4          AFG      Asia  Afghanistan  2020-02-28 00:00:00.000000  38928341.0
# ...        ...       ...          ...                         ...         ...
# 89700      ZWE    Africa     Zimbabwe  2021-06-03 00:00:00.000000  14862927.0
# 89701      ZWE    Africa     Zimbabwe  2021-06-04 00:00:00.000000  14862927.0
# 89702      ZWE    Africa     Zimbabwe  2021-06-05 00:00:00.000000  14862927.0
# 89703      ZWE    Africa     Zimbabwe  2021-06-06 00:00:00.000000  14862927.0
# 89704      ZWE    Africa     Zimbabwe  2021-06-07 00:00:00.000000  14862927.0
#
#        total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0              1.0        1.0                 NaN           NaN         NaN
# 1              1.0        0.0                 NaN           NaN         NaN
# 2              1.0        0.0                 NaN           NaN         NaN
# 3              1.0        0.0                 NaN           NaN         NaN
# 4              1.0        0.0                 NaN           NaN         NaN
# ...            ...        ...                 ...           ...         ...
# 89700      39092.0       61.0              34.000        1604.0         5.0
# 89701      39144.0       52.0              32.286        1605.0         1.0
# 89702      39168.0       24.0              33.571        1605.0         0.0
# 89703      39189.0       21.0              35.000        1606.0         1.0
# 89704      39238.0       49.0              39.571        1611.0         5.0
#
#        ...  new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# 0      ...                              NaN                NaN           NaN
# 1      ...                              NaN                NaN           NaN
# 2      ...                              NaN                NaN           NaN
# 3      ...                              NaN                NaN           NaN
# 4      ...                              NaN                NaN           NaN
# ...    ...                              ...                ...           ...
# 89700  ...                            0.115               1.20           NaN
# 89701  ...                            0.125               1.19           NaN
# 89702  ...                            0.106               1.19           NaN
# 89703  ...                            0.115               1.19           NaN
# 89704  ...                            0.163                NaN           NaN
#
#        icu_patients_per_million  hosp_patients  hosp_patients_per_million  \
# 0                           NaN            NaN                        NaN
# 1                           NaN            NaN                        NaN
# 2                           NaN            NaN                        NaN
# 3                           NaN            NaN                        NaN
# 4                           NaN            NaN                        NaN
# ...                         ...            ...                        ...
# 89700                       NaN            NaN                        NaN
# 89701                       NaN            NaN                        NaN
# 89702                       NaN            NaN                        NaN
# 89703                       NaN            NaN                        NaN
# 89704                       NaN            NaN                        NaN
#
#        weekly_icu_admissions  weekly_icu_admissions_per_million  \
# 0                        NaN                                NaN
# 1                        NaN                                NaN
# 2                        NaN                                NaN
# 3                        NaN                                NaN
# 4                        NaN                                NaN
# ...                      ...                                ...
# 89700                    NaN                                NaN
# 89701                    NaN                                NaN
# 89702                    NaN                                NaN
# 89703                    NaN                                NaN
# 89704                    NaN                                NaN
#
#        weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 0                         NaN                                 NaN
# 1                         NaN                                 NaN
# 2                         NaN                                 NaN
# 3                         NaN                                 NaN
# 4                         NaN                                 NaN
# ...                       ...                                 ...
# 89700                     NaN                                 NaN
# 89701                     NaN                                 NaN
# 89702                     NaN                                 NaN
# 89703                     NaN                                 NaN
# 89704                     NaN                                 NaN
#
# [89705 rows x 26 columns]

# %%
#to read cv table
ps.sqldf("select * from cv where continent is not null order by 3,4")
# Out:
#       iso_code continent     location                        date  \
# 0          AFG      Asia  Afghanistan  2020-02-24 00:00:00.000000
# 1          AFG      Asia  Afghanistan  2020-02-25 00:00:00.000000
# 2          AFG      Asia  Afghanistan  2020-02-26 00:00:00.000000
# 3          AFG      Asia  Afghanistan  2020-02-27 00:00:00.000000
# 4          AFG      Asia  Afghanistan  2020-02-28 00:00:00.000000
# ...        ...       ...          ...                         ...
# 89700      ZWE    Africa     Zimbabwe  2021-06-03 00:00:00.000000
# 89701      ZWE    Africa     Zimbabwe  2021-06-04 00:00:00.000000
# 89702      ZWE    Africa     Zimbabwe  2021-06-05 00:00:00.000000
# 89703      ZWE    Africa     Zimbabwe  2021-06-06 00:00:00.000000
# 89704      ZWE    Africa     Zimbabwe  2021-06-07 00:00:00.000000
#
#        total_tests  total_tests_per_thousand  new_tests_per_thousand  \
# 0              NaN                       NaN                     NaN
# 1              NaN                       NaN                     NaN
# 2              NaN                       NaN                     NaN
# 3              NaN                       NaN                     NaN
# 4              NaN                       NaN                     NaN
# ...            ...                       ...                     ...
# 89700     557596.0                    37.516                   0.122
# 89701     559887.0                    37.670                   0.154
# 89702     561819.0                    37.800                   0.130
# 89703     562867.0                    37.871                   0.071
# 89704          NaN                       NaN                     NaN
#
#        new_tests_smoothed  new_tests_smoothed_per_thousand  positive_rate  \
# 0                     NaN                              NaN            NaN
# 1                     NaN                              NaN            NaN
# 2                     NaN                              NaN            NaN
# 3                     NaN                              NaN            NaN
# 4                     NaN                              NaN            NaN
# ...                   ...                              ...            ...
# 89700              1863.0                            0.125          0.018
# 89701              1928.0                            0.130          0.017
# 89702              1914.0                            0.129          0.018
# 89703              1955.0                            0.132          0.018
# 89704                 NaN                              NaN            NaN
#
#        ...  gdp_per_capita extreme_poverty  cardiovasc_death_rate  \
# 0      ...        1803.987             NaN                597.029
# 1      ...        1803.987             NaN                597.029
# 2      ...        1803.987             NaN                597.029
# 3      ...        1803.987             NaN                597.029
# 4      ...        1803.987             NaN                597.029
# ...    ...             ...             ...                    ...
# 89700  ...        1899.775            21.4                307.846
# 89701  ...        1899.775            21.4                307.846
# 89702  ...        1899.775            21.4                307.846
# 89703  ...        1899.775            21.4                307.846
# 89704  ...        1899.775            21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 89700                 1.82             1.6          30.7
# 89701                 1.82             1.6          30.7
# 89702                 1.82             1.6          30.7
# 89703                 1.82             1.6          30.7
# 89704                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 89700                  36.791                         1.7            61.49
# 89701                  36.791                         1.7            61.49
# 89702                  36.791                         1.7            61.49
# 89703                  36.791                         1.7            61.49
# 89704                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 89700                    0.571
# 89701                    0.571
# 89702                    0.571
# 89703                    0.571
# 89704                    0.571
#
# [89705 rows x 37 columns]

# %%
ps.sqldf("select location, date, total_cases, new_cases, total_deaths, population from cd where continent is not null order by 1,2")
# Out:
#           location                        date  total_cases  new_cases  \
# 0      Afghanistan  2020-02-24 00:00:00.000000          1.0        1.0
# 1      Afghanistan  2020-02-25 00:00:00.000000          1.0        0.0
# 2      Afghanistan  2020-02-26 00:00:00.000000          1.0        0.0
# 3      Afghanistan  2020-02-27 00:00:00.000000          1.0        0.0
# 4      Afghanistan  2020-02-28 00:00:00.000000          1.0        0.0
# ...            ...                         ...          ...        ...
# 89700     Zimbabwe  2021-06-03 00:00:00.000000      39092.0       61.0
# 89701     Zimbabwe  2021-06-04 00:00:00.000000      39144.0       52.0
# 89702     Zimbabwe  2021-06-05 00:00:00.000000      39168.0       24.0
# 89703     Zimbabwe  2021-06-06 00:00:00.000000      39189.0       21.0
# 89704     Zimbabwe  2021-06-07 00:00:00.000000      39238.0       49.0
#
#        total_deaths  population
# 0               NaN  38928341.0
# 1               NaN  38928341.0
# 2               NaN  38928341.0
# 3               NaN  38928341.0
# 4               NaN  38928341.0
# ...             ...         ...
# 89700        1604.0  14862927.0
# 89701        1605.0  14862927.0
# 89702        1605.0  14862927.0
# 89703        1606.0  14862927.0
# 89704        1611.0  14862927.0
#
# [89705 rows x 6 columns]

# %%
# shows likelihood of dying if you contract covid in US
ps.sqldf("select location, date, total_cases, total_deaths, (total_deaths/total_cases)*100 as DeathPercentage from cd where location like '%states%' and continent is not null  order by 1,2")
# Out:
#           location                        date  total_cases  total_deaths  \
# 0    United States  2020-01-22 00:00:00.000000          1.0           NaN
# 1    United States  2020-01-23 00:00:00.000000          1.0           NaN
# 2    United States  2020-01-24 00:00:00.000000          2.0           NaN
# 3    United States  2020-01-25 00:00:00.000000          2.0           NaN
# 4    United States  2020-01-26 00:00:00.000000          5.0           NaN
# ..             ...                         ...          ...           ...
# 498  United States  2021-06-03 00:00:00.000000   33326437.0      596491.0
# 499  United States  2021-06-04 00:00:00.000000   33343297.0      597001.0
# 500  United States  2021-06-05 00:00:00.000000   33357205.0      597377.0
# 501  United States  2021-06-06 00:00:00.000000   33362600.0      597628.0
# 502  United States  2021-06-07 00:00:00.000000   33378096.0      597952.0
#
#      DeathPercentage
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 498         1.789843
# 499         1.790468
# 500         1.790848
# 501         1.791311
# 502         1.791450
#
# [503 rows x 5 columns]

# %%
# total cases vs the population
ps.sqldf("select location, date, population, total_cases, (total_cases/population)*100 as PercentPopulationInfected from cd where location like '%states%' and continent is not null order by 1,2")
# Out:
#           location                        date   population  total_cases  \
# 0    United States  2020-01-22 00:00:00.000000  331002647.0          1.0
# 1    United States  2020-01-23 00:00:00.000000  331002647.0          1.0
# 2    United States  2020-01-24 00:00:00.000000  331002647.0          2.0
# 3    United States  2020-01-25 00:00:00.000000  331002647.0          2.0
# 4    United States  2020-01-26 00:00:00.000000  331002647.0          5.0
# ..             ...                         ...          ...          ...
# 498  United States  2021-06-03 00:00:00.000000  331002647.0   33326437.0
# 499  United States  2021-06-04 00:00:00.000000  331002647.0   33343297.0
# 500  United States  2021-06-05 00:00:00.000000  331002647.0   33357205.0
# 501  United States  2021-06-06 00:00:00.000000  331002647.0   33362600.0
# 502  United States  2021-06-07 00:00:00.000000  331002647.0   33378096.0
#
#      PercentPopulationInfected
# 0                 3.021124e-07
# 1                 3.021124e-07
# 2                 6.042248e-07
# 3                 6.042248e-07
# 4                 1.510562e-06
# ..                         ...
# 498               1.006833e+01
# 499               1.007342e+01
# 500               1.007762e+01
# 501               1.007925e+01
# 502               1.008394e+01
#
# [503 rows x 5 columns]

# %%
# looking for countries with highest infection rate compated to population
ps.sqldf("select location, population, MAX(total_cases) as HighestInfectionCount, MAX((total_cases/population))*100 as PercentPopulationInfected from cd where continent is not null group by location, population order by PercentPopulationInfected desc")
# Out:
#                      location  population  HighestInfectionCount  \
# 0                     Andorra     77265.0                13777.0
# 1                  Montenegro    628062.0                99834.0
# 2                     Czechia  10708982.0              1663607.0
# 3                  San Marino     33938.0                 5090.0
# 4                     Bahrain   1701583.0               252600.0
# ..                        ...         ...                    ...
# 215                     Tonga    105697.0                    NaN
# 216              Turkmenistan   6031187.0                    NaN
# 217  Turks and Caicos Islands     38718.0                    NaN
# 218                    Tuvalu     11792.0                    NaN
# 219         Wallis and Futuna     11246.0                    NaN
#
#      PercentPopulationInfected
# 0                    17.830842
# 1                    15.895564
# 2                    15.534689
# 3                    14.997937
# 4                    14.845000
# ..                         ...
# 215                        NaN
# 216                        NaN
# 217                        NaN
# 218                        NaN
# 219                        NaN
#
# [220 rows x 4 columns]

# %%
# showing countries with highest death count per population
ps.sqldf("select location, MAX(cast(total_deaths as int)) as TotalDeathCount from cd where continent is not null group by location order by TotalDeathCount desc")
# Out:
#                             location  TotalDeathCount
# 0                      United States         597952.0
# 1                             Brazil         474414.0
# 2                              India         351309.0
# 3                             Mexico         228838.0
# 4                               Peru         186511.0
# ..                               ...              ...
# 215           British Virgin Islands              NaN
# 216  Bonaire Sint Eustatius and Saba              NaN
# 217                          Bermuda              NaN
# 218                            Aruba              NaN
# 219                         Anguilla              NaN
#
# [220 rows x 2 columns]

# %%
# showing continent with highest death count
ps.sqldf("select continent, MAX(cast(total_deaths as int)) as TotalDeathCount from cd  where continent is not null group by continent order by TotalDeathCount desc")
# Out:
#        continent  TotalDeathCount
# 0  North America           597952
# 1  South America           474414
# 2           Asia           351309
# 3         Europe           128104
# 4         Africa            57063
# 5        Oceania              910

# %%
# let's break things down by continent
ps.sqldf("select location, MAX(cast(total_deaths as int)) as TotalDeathCount from cd  where continent is null group by location order by TotalDeathCount desc")
# Out:
#          location  TotalDeathCount
# 0           World          3736961
# 1          Europe          1082304
# 2   South America           919460
# 3   North America           887715
# 4  European Union           729761
# 5            Asia           713778
# 6          Africa           132584
# 7         Oceania             1105
# 8   International               15

# %%
# Global numbers
ps.sqldf("select location, date, total_cases, total_deaths, (total_deaths/total_cases)*100 as DeathPercentage from cd where continent is not null order by 1,2")
# Out:
#           location                        date  total_cases  total_deaths  \
# 0      Afghanistan  2020-02-24 00:00:00.000000          1.0           NaN
# 1      Afghanistan  2020-02-25 00:00:00.000000          1.0           NaN
# 2      Afghanistan  2020-02-26 00:00:00.000000          1.0           NaN
# 3      Afghanistan  2020-02-27 00:00:00.000000          1.0           NaN
# 4      Afghanistan  2020-02-28 00:00:00.000000          1.0           NaN
# ...            ...                         ...          ...           ...
# 89700     Zimbabwe  2021-06-03 00:00:00.000000      39092.0        1604.0
# 89701     Zimbabwe  2021-06-04 00:00:00.000000      39144.0        1605.0
# 89702     Zimbabwe  2021-06-05 00:00:00.000000      39168.0        1605.0
# 89703     Zimbabwe  2021-06-06 00:00:00.000000      39189.0        1606.0
# 89704     Zimbabwe  2021-06-07 00:00:00.000000      39238.0        1611.0
#
#        DeathPercentage
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 89700         4.103141
# 89701         4.100245
# 89702         4.097733
# 89703         4.098089
# 89704         4.105714
#
# [89705 rows x 5 columns]

# %%
ps.sqldf("select date, SUM(new_cases) as TotalCases, SUM(cast(new_deaths as int)) as TotalDeaths, SUM(cast(new_deaths as int))/SUM(new_cases)*100 as DeathPercentage from cd where continent is not null group by date order by 1,2")
# Out:
#                            date  TotalCases  TotalDeaths  DeathPercentage
# 0    2020-01-01 00:00:00.000000         NaN          NaN              NaN
# 1    2020-01-02 00:00:00.000000         NaN          NaN              NaN
# 2    2020-01-03 00:00:00.000000         NaN          NaN              NaN
# 3    2020-01-04 00:00:00.000000         NaN          NaN              NaN
# 4    2020-01-05 00:00:00.000000         NaN          NaN              NaN
# ..                          ...         ...          ...              ...
# 519  2021-06-03 00:00:00.000000    489117.0       9909.0         2.025896
# 520  2021-06-04 00:00:00.000000    419717.0      10939.0         2.606280
# 521  2021-06-05 00:00:00.000000    398361.0       9167.0         2.301179
# 522  2021-06-06 00:00:00.000000    322641.0       7149.0         2.215775
# 523  2021-06-07 00:00:00.000000    320618.0       8076.0         2.518885
#
# [524 rows x 4 columns]

# %%
ps.sqldf("select SUM(new_cases) as total_cases, SUM(cast(new_deaths as int)) as total_deaths, SUM(cast(new_deaths as int))/SUM(new_cases)*100 as DeathPercentage from cd where continent is not null order by 1,2")
# Out:
#    total_cases  total_deaths  DeathPercentage
# 0  173155430.0       3736008         2.157604

# %%
# let's look at cv - Covid Vaccinations table
ps.sqldf("select * from cv")
# Out:
#       iso_code continent     location                        date  \
# 0          AFG      Asia  Afghanistan  2020-02-24 00:00:00.000000
# 1          AFG      Asia  Afghanistan  2020-02-25 00:00:00.000000
# 2          AFG      Asia  Afghanistan  2020-02-26 00:00:00.000000
# 3          AFG      Asia  Afghanistan  2020-02-27 00:00:00.000000
# 4          AFG      Asia  Afghanistan  2020-02-28 00:00:00.000000
# ...        ...       ...          ...                         ...
# 94153      ZWE    Africa     Zimbabwe  2021-06-03 00:00:00.000000
# 94154      ZWE    Africa     Zimbabwe  2021-06-04 00:00:00.000000
# 94155      ZWE    Africa     Zimbabwe  2021-06-05 00:00:00.000000
# 94156      ZWE    Africa     Zimbabwe  2021-06-06 00:00:00.000000
# 94157      ZWE    Africa     Zimbabwe  2021-06-07 00:00:00.000000
#
#        total_tests  total_tests_per_thousand  new_tests_per_thousand  \
# 0              NaN                       NaN                     NaN
# 1              NaN                       NaN                     NaN
# 2              NaN                       NaN                     NaN
# 3              NaN                       NaN                     NaN
# 4              NaN                       NaN                     NaN
# ...            ...                       ...                     ...
# 94153     557596.0                    37.516                   0.122
# 94154     559887.0                    37.670                   0.154
# 94155     561819.0                    37.800                   0.130
# 94156     562867.0                    37.871                   0.071
# 94157          NaN                       NaN                     NaN
#
#        new_tests_smoothed  new_tests_smoothed_per_thousand  positive_rate  \
# 0                     NaN                              NaN            NaN
# 1                     NaN                              NaN            NaN
# 2                     NaN                              NaN            NaN
# 3                     NaN                              NaN            NaN
# 4                     NaN                              NaN            NaN
# ...                   ...                              ...            ...
# 94153              1863.0                            0.125          0.018
# 94154              1928.0                            0.130          0.017
# 94155              1914.0                            0.129          0.018
# 94156              1955.0                            0.132          0.018
# 94157                 NaN                              NaN            NaN
#
#        ...  gdp_per_capita extreme_poverty  cardiovasc_death_rate  \
# 0      ...        1803.987             NaN                597.029
# 1      ...        1803.987             NaN                597.029
# 2      ...        1803.987             NaN                597.029
# 3      ...        1803.987             NaN                597.029
# 4      ...        1803.987             NaN                597.029
# ...    ...             ...             ...                    ...
# 94153  ...        1899.775            21.4                307.846
# 94154  ...        1899.775            21.4                307.846
# 94155  ...        1899.775            21.4                307.846
# 94156  ...        1899.775            21.4                307.846
# 94157  ...        1899.775            21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 94153                 1.82             1.6          30.7
# 94154                 1.82             1.6          30.7
# 94155                 1.82             1.6          30.7
# 94156                 1.82             1.6          30.7
# 94157                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 94153                  36.791                         1.7            61.49
# 94154                  36.791                         1.7            61.49
# 94155                  36.791                         1.7            61.49
# 94156                  36.791                         1.7            61.49
# 94157                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 94153                    0.571
# 94154                    0.571
# 94155                    0.571
# 94156                    0.571
# 94157                    0.571
#
# [94158 rows x 37 columns]

# %%
# let's join two tables
ps.sqldf("select * from cd join cv on cd.location = cv.location and cd.date = cv.date")
# Out:
#       iso_code continent     location                        date  population  \
# 0          AFG      Asia  Afghanistan  2020-02-24 00:00:00.000000  38928341.0
# 1          AFG      Asia  Afghanistan  2020-02-25 00:00:00.000000  38928341.0
# 2          AFG      Asia  Afghanistan  2020-02-26 00:00:00.000000  38928341.0
# 3          AFG      Asia  Afghanistan  2020-02-27 00:00:00.000000  38928341.0
# 4          AFG      Asia  Afghanistan  2020-02-28 00:00:00.000000  38928341.0
# ...        ...       ...          ...                         ...         ...
# 94153      ZWE    Africa     Zimbabwe  2021-06-03 00:00:00.000000  14862927.0
# 94154      ZWE    Africa     Zimbabwe  2021-06-04 00:00:00.000000  14862927.0
# 94155      ZWE    Africa     Zimbabwe  2021-06-05 00:00:00.000000  14862927.0
# 94156      ZWE    Africa     Zimbabwe  2021-06-06 00:00:00.000000  14862927.0
# 94157      ZWE    Africa     Zimbabwe  2021-06-07 00:00:00.000000  14862927.0
#
#        total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0              1.0        1.0                 NaN           NaN         NaN
# 1              1.0        0.0                 NaN           NaN         NaN
# 2              1.0        0.0                 NaN           NaN         NaN
# 3              1.0        0.0                 NaN           NaN         NaN
# 4              1.0        0.0                 NaN           NaN         NaN
# ...            ...        ...                 ...           ...         ...
# 94153      39092.0       61.0              34.000        1604.0         5.0
# 94154      39144.0       52.0              32.286        1605.0         1.0
# 94155      39168.0       24.0              33.571        1605.0         0.0
# 94156      39189.0       21.0              35.000        1606.0         1.0
# 94157      39238.0       49.0              39.571        1611.0         5.0
#
#        ...  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0      ...        1803.987              NaN                597.029
# 1      ...        1803.987              NaN                597.029
# 2      ...        1803.987              NaN                597.029
# 3      ...        1803.987              NaN                597.029
# 4      ...        1803.987              NaN                597.029
# ...    ...             ...              ...                    ...
# 94153  ...        1899.775             21.4                307.846
# 94154  ...        1899.775             21.4                307.846
# 94155  ...        1899.775             21.4                307.846
# 94156  ...        1899.775             21.4                307.846
# 94157  ...        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 94153                 1.82             1.6          30.7
# 94154                 1.82             1.6          30.7
# 94155                 1.82             1.6          30.7
# 94156                 1.82             1.6          30.7
# 94157                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 94153                  36.791                         1.7            61.49
# 94154                  36.791                         1.7            61.49
# 94155                  36.791                         1.7            61.49
# 94156                  36.791                         1.7            61.49
# 94157                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 94153                    0.571
# 94154                    0.571
# 94155                    0.571
# 94156                    0.571
# 94157                    0.571
#
# [94158 rows x 63 columns]

# %%
# looking at total population vs vaccinations
ps.sqldf("select cd.continent, cd.location, cd.date, cd.population, cv.new_vaccinations, SUM(cast(cv.new_vaccinations as int)) OVER(partition by cd.location order by cd.location, cd.date) as RollingPeopleVaxed from cd join cv on cd.location = cv.location and cd.date = cv.date where cd.continent is not null order by 2,3")
# Out:
#       continent     location                        date  population  \
# 0          Asia  Afghanistan  2020-02-24 00:00:00.000000  38928341.0
# 1          Asia  Afghanistan  2020-02-25 00:00:00.000000  38928341.0
# 2          Asia  Afghanistan  2020-02-26 00:00:00.000000  38928341.0
# 3          Asia  Afghanistan  2020-02-27 00:00:00.000000  38928341.0
# 4          Asia  Afghanistan  2020-02-28 00:00:00.000000  38928341.0
# ...         ...          ...                         ...         ...
# 89700    Africa     Zimbabwe  2021-06-03 00:00:00.000000  14862927.0
# 89701    Africa     Zimbabwe  2021-06-04 00:00:00.000000  14862927.0
# 89702    Africa     Zimbabwe  2021-06-05 00:00:00.000000  14862927.0
# 89703    Africa     Zimbabwe  2021-06-06 00:00:00.000000  14862927.0
# 89704    Africa     Zimbabwe  2021-06-07 00:00:00.000000  14862927.0
#
#        new_vaccinations  RollingPeopleVaxed
# 0                   NaN                 NaN
# 1                   NaN                 NaN
# 2                   NaN                 NaN
# 3                   NaN                 NaN
# 4                   NaN                 NaN
# ...                 ...                 ...
# 89700            8290.0           1047190.0
# 89701            7734.0           1054924.0
# 89702            5713.0           1060637.0
# 89703               NaN           1060637.0
# 89704               NaN           1060637.0
#
# [89705 rows x 6 columns]

# %%
# using CTEs
ps.sqldf("WITH PopvsVac (continent, location, date, population, new_vaccinations, RollingPeopleVaxed)"
         "AS (select cd.continent, cd.location, cd.date, cd.population, cv.new_vaccinations, SUM(cast(cv.new_vaccinations as int)) OVER(partition by cd.location order by cd.location, cd.date) as RollingPeopleVaxed from cd join cv on cd.location = cv.location and cd.date = cv.date where cd.continent is not null)"
"SELECT *, (RollingPeopleVaxed/population)*100 PopulationVaxedPercentage FROM PopvsVac")
# Out:
#       continent     location                        date  population  \
# 0          Asia  Afghanistan  2020-02-24 00:00:00.000000  38928341.0
# 1          Asia  Afghanistan  2020-02-25 00:00:00.000000  38928341.0
# 2          Asia  Afghanistan  2020-02-26 00:00:00.000000  38928341.0
# 3          Asia  Afghanistan  2020-02-27 00:00:00.000000  38928341.0
# 4          Asia  Afghanistan  2020-02-28 00:00:00.000000  38928341.0
# ...         ...          ...                         ...         ...
# 89700    Africa     Zimbabwe  2021-06-03 00:00:00.000000  14862927.0
# 89701    Africa     Zimbabwe  2021-06-04 00:00:00.000000  14862927.0
# 89702    Africa     Zimbabwe  2021-06-05 00:00:00.000000  14862927.0
# 89703    Africa     Zimbabwe  2021-06-06 00:00:00.000000  14862927.0
# 89704    Africa     Zimbabwe  2021-06-07 00:00:00.000000  14862927.0
#
#        new_vaccinations  RollingPeopleVaxed  PopulationVaxedPercentage
# 0                   NaN                 NaN                        NaN
# 1                   NaN                 NaN                        NaN
# 2                   NaN                 NaN                        NaN
# 3                   NaN                 NaN                        NaN
# 4                   NaN                 NaN                        NaN
# ...                 ...                 ...                        ...
# 89700            8290.0           1047190.0                   7.045651
# 89701            7734.0           1054924.0                   7.097687
# 89702            5713.0           1060637.0                   7.136125
# 89703               NaN           1060637.0                   7.136125
# 89704               NaN           1060637.0                   7.136125
#
# [89705 rows x 7 columns]

# %%
# # temp table
# ps.sqldf("DROP TABLE if exists #PercentPopulationVaxed Create Table #PercentPopulationVaxed (Continent nvarchar(255), location nvarchar(255), date datetime, population numeric, new_vaccinations numeric, RollingPeopleVaxed numeric)"
#         "Insert into PercentPopulationVaxed"
#         "select cd.continent, cd.location, cd.date, cd.population, cv.new_vaccinations, SUM(cast(cv.new_vaccinations as int)) OVER(partition by cd.location order by cd.location, cd.date) as RollingPeopleVaxed"
#         "from cd join cv on cd.location = cv.location and cd.date = cv.date"
#         "where cd.continentis not null"
#         "select *, (RollingPeopleVaxed/population)*100"
#         "from #PercentPopulationVaxed")

# %% [markdown]
# #### Getting tables ready for Tableau

# %%
ps.sqldf("select SUM(new_cases) as total_cases, SUM(cast(new_deaths as int)) as total_deaths, SUM(cast(new_deaths as int))/SUM(new_cases)*100 as DeathPercentage from cd where continent is not null order by 1,2")
# Out:
#    total_cases  total_deaths  DeathPercentage
# 0  173155430.0       3736008         2.157604

# %%
# let's break things down by continent excluding 'World', 'European Union', 'International'
ps.sqldf("select location, SUM(cast(new_deaths as int)) as TotalDeathCount from cd  where continent is null and location not in ('World', 'European Union', 'International') group by location order by TotalDeathCount desc")
# Out:
#         location  TotalDeathCount
# 0         Europe          1082304
# 1  South America           918539
# 2  North America           887715
# 3           Asia           713761
# 4         Africa           132584
# 5        Oceania             1105

# %%
pd.set_option('display.max_rows', None)

# %%
# looking for countries with highest infection rate compated to population
ps.sqldf("select location, population, MAX(total_cases) as HighestInfectionCount, MAX((total_cases/population))*100 as PercentPopulationInfected from cd group by location, population order by PercentPopulationInfected desc")
# Out:
#                              location    population  HighestInfectionCount  \
# 0                             Andorra  7.726500e+04                13777.0
# 1                          Montenegro  6.280620e+05                99834.0
# 2                             Czechia  1.070898e+07              1663607.0
# 3                          San Marino  3.393800e+04                 5090.0
# 4                             Bahrain  1.701583e+06               252600.0
# 5                          Seychelles  9.834000e+04                12466.0
# 6                            Maldives  5.405420e+05                68502.0
# 7                            Slovenia  2.078932e+06               255432.0
# 8                          Luxembourg  6.259760e+05                70256.0
# 9                              Sweden  1.009927e+07              1078062.0
# 10                             Serbia  6.804596e+06               713840.0
# 203   Bonaire Sint Eustatius and Saba  2.622100e+04                    NaN
# 204            British Virgin Islands  3.023700e+04                    NaN
# 205                    Cayman Islands  6.572000e+04                    NaN
# 206                      Cook Islands  1.756400e+04                    NaN
# 207                           Curacao  1.641000e+05                    NaN
# 208                    Faeroe Islands  4.886500e+04                    NaN
# 209                  Falkland Islands  3.483000e+03                    NaN
# 210                  French Polynesia  2.809040e+05                    NaN
# 211                         Gibraltar  3.369100e+04                    NaN
# 212                         Greenland  5.677200e+04                    NaN
# 213                          Guernsey  6.705200e+04                    NaN
# 214                     International           NaN                  721.0
# 215                       Isle of Man  8.503200e+04                    NaN
# 216                            Jersey  1.010730e+05                    NaN
# 217                             Macao  6.493420e+05                    NaN
# 218                        Montserrat  4.999000e+03                    NaN
# 219                             Nauru  1.083400e+04                    NaN
# 220                     New Caledonia  2.854910e+05                    NaN
# 221                   Northern Cyprus           NaN                    NaN
# 222                      Saint Helena  6.071000e+03                    NaN
# 223         Sint Maarten (Dutch part)  4.288200e+04                    NaN
# 224                             Tonga  1.056970e+05                    NaN
# 225                      Turkmenistan  6.031187e+06                    NaN
# 226          Turks and Caicos Islands  3.871800e+04                    NaN
# 227                            Tuvalu  1.179200e+04                    NaN
# 228                 Wallis and Futuna  1.124600e+04                    NaN
#
#      PercentPopulationInfected
# 0                    17.830842
# 1                    15.895564
# 2                    15.534689
# 3                    14.997937
# 4                    14.845000
# 5                    12.676429
# 6                    12.672836
# 7                    12.286693
# 8                    11.223433
# 9                    10.674653
# 10                   10.490557
# 11                   10.158466
# 12                   10.083936
# 13                    9.873817
# 14                    9.811698
# 15                    9.699971
# 16                    9.243369
# 17                    9.176973
# 18                    8.873038
# 19                    8.848836
# 20                    8.800897
# 21                    8.758829
# 22                    8.710954
# 23                    8.365779
# 24                    8.344304
# 25                    8.318197
# 26                    8.069322
# 27                    7.990339
# 28                    7.935427
# 29                    7.929719
# 30                    7.924063
# 31                    7.597321
# 32                    7.594358
# 33                    7.532716
# 34                    7.506112
# 35                    7.462154
# 36                    7.459897
# 37                    7.279276
# 38                    7.251170
# 39                    7.184658
# 40                    7.151585
# 41                    7.151302
# 42                    7.061345
# 43                    7.002266
# 44                    6.923737
# 45                    6.910145
# 46                    6.685324
# 47                    6.603348
# 48                    6.515755
# 49                    6.390786
# 50                    6.333747
# 51                    6.304633
# 52                    6.276601
# 53                    6.230464
# 54                    6.077254
# 55                    6.039927
# 56                    6.015951
# 57                    5.915221
# 58                    5.608534
# 59                    5.602099
# 60                    5.541207
# 61                    5.364235
# 62                    5.271566
# 63                    5.200502
# 64                    4.967626
# 65                    4.600181
# 66                    4.428464
# 67                    4.407904
# 68                    4.237574
# 69                    3.935180
# 70                    3.714446
# 71                    3.537523
# 72                    3.478646
# 73                    3.337454
# 74                    3.316723
# 75                    3.301521
# 76                    3.244044
# 77                    3.057612
# 78                    3.055804
# 79                    3.018542
# 80                    2.866104
# 81                    2.861409
# 82                    2.798033
# 83                    2.783800
# 84                    2.731439
# 85                    2.470419
# 86                    2.452743
# 87                    2.447114
# 88                    2.405326
# 89                    2.343854
# 90                    2.325618
# 91                    2.252596
# 92                    2.227527
# 93                    2.101187
# 94                    2.065405
# 95                    2.030058
# 96                    1.922036
# 97                    1.920879
# 98                    1.914910
# 99                    1.888242
# 100                   1.871164
# 101                   1.683554
# 102                   1.648340
# 103                   1.645185
# 104                   1.608738
# 105                   1.463839
# 106                   1.412956
# 107                   1.403064
# 108                   1.325224
# 109                   1.317599
# 110                   1.289723
# 111                   1.170544
# 112                   1.164438
# 113                   1.143057
# 114                   1.133341
# 115                   1.104852
# 116                   1.073640
# 117                   1.063356
# 118                   0.971263
# 119                   0.856736
# 120                   0.681123
# 121                   0.614832
# 122                   0.604211
# 123                   0.588877
# 124                   0.548114
# 125                   0.505870
# 126                   0.493632
# 127                   0.447335
# 128                   0.426977
# 129                   0.423289
# 130                   0.367818
# 131                   0.321062
# 132                   0.304650
# 133                   0.303248
# 134                   0.299384
# 135                   0.297331
# 136                   0.282998
# 137                   0.265496
# 138                   0.263999
# 139                   0.262623
# 140                   0.261144
# 141                   0.257716
# 142                   0.249123
# 143                   0.248359
# 144                   0.237487
# 145                   0.227624
# 146                   0.220707
# 147                   0.217938
# 148                   0.210829
# 149                   0.208344
# 150                   0.207666
# 151                   0.192429
# 152                   0.183011
# 153                   0.180046
# 154                   0.179838
# 155                   0.177472
# 156                   0.163576
# 157                   0.158264
# 158                   0.156039
# 159                   0.150742
# 160                   0.147026
# 161                   0.143087
# 162                   0.141023
# 163                   0.139531
# 164                   0.135365
# 165                   0.126860
# 166                   0.118452
# 167                   0.117971
# 168                   0.117288
# 169                   0.114644
# 170                   0.112928
# 171                   0.109091
# 172                   0.095482
# 173                   0.092920
# 174                   0.083775
# 175                   0.082109
# 176                   0.080924
# 177                   0.070624
# 178                   0.066666
# 179                   0.064358
# 180                   0.055825
# 181                   0.055774
# 182                   0.052752
# 183                   0.048248
# 184                   0.045278
# 185                   0.041419
# 186                   0.037224
# 187                   0.030075
# 188                   0.027049
# 189                   0.022839
# 190                   0.022469
# 191                   0.009274
# 192                   0.006757
# 193                   0.006347
# 194                   0.002912
# 195                   0.001674
# 196                   0.001512
# 197                   0.001302
# 198                   0.000869
# 199                   0.000852
# 200                        NaN
# 201                        NaN
# 202                        NaN
# 203                        NaN
# 204                        NaN
# 205                        NaN
# 206                        NaN
# 207                        NaN
# 208                        NaN
# 209                        NaN
# 210                        NaN
# 211                        NaN
# 212                        NaN
# 213                        NaN
# 214                        NaN
# 215                        NaN
# 216                        NaN
# 217                        NaN
# 218                        NaN
# 219                        NaN
# 220                        NaN
# 221                        NaN
# 222                        NaN
# 223                        NaN
# 224                        NaN
# 225                        NaN
# 226                        NaN
# 227                        NaN
# 228                        NaN

# %%
# looking for countries with highest infection rate compated to population
s= ps.sqldf("select location, population, date, MAX(total_cases) as HighestInfectionCount, MAX((total_cases/population))*100 as PercentPopulationInfected from cd group by location, population, date order by PercentPopulationInfected desc")

# %%
s.to_excel('data/Tableau Table 4.xlsx')
